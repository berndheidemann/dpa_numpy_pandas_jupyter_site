# %% [markdown]
# # 🐼 Pandas Übungen
#
# Dieses Notebook ist bereits für dich vorbereitet. NumPy und Pandas sind installiert.
#
# **Bearbeite hier die Aufgaben aus den Arbeitsblättern!**

# %%
# Pandas und NumPy importieren
import pandas as pd
import numpy as np

# Versionen prüfen
print(f"Pandas Version: {pd.__version__}")
print(f"NumPy Version: {np.__version__}")
print("\n✅ Pandas ist bereit!")

# %% [markdown]
# ## CSV-Dateien laden
#
# In JupyterLite kannst du CSV-Dateien direkt von URLs laden:
#
# ```python
# # Beispiel: Datei von URL laden
# url = "https://berndheidemann.github.io/dpa_numpy_pandas_jupyter_site/assets/files/games.csv"
# df = pd.read_csv(url)
# ```

# %%
# Beispiel: Games-Datensatz laden
url = "https://berndheidemann.github.io/dpa_numpy_pandas_jupyter_site/assets/files/games.csv"
games = pd.read_csv(url)

print(f"Datensatz geladen: {games.shape[0]} Zeilen, {games.shape[1]} Spalten")
games.head()

# %% [markdown]
# ## Dein Arbeitsbereich
#
# Schreibe deinen Code in die Zellen unten:

# %%
# Aufgabe 1: Dein Code hier

# %%
# Aufgabe 2: Dein Code hier

# %%
# Aufgabe 3: Dein Code hier

# %%
# Weitere Aufgaben...
