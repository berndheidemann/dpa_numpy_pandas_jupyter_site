# %% [markdown]
# # 🔢 NumPy Übungen
#
# Dieses Notebook ist bereits für dich vorbereitet. NumPy und Pandas sind installiert.
#
# **Bearbeite hier die Aufgaben aus den Arbeitsblättern!**

# %%
# NumPy importieren
import numpy as np

# Version prüfen
print(f"NumPy Version: {np.__version__}")
print("\n✅ NumPy ist bereit!")

# %% [markdown]
# ## Dein Arbeitsbereich
#
# Schreibe deinen Code in die Zellen unten. Du kannst jederzeit neue Zellen hinzufügen:
# - **B** = Neue Zelle unten
# - **A** = Neue Zelle oben
# - **Shift+Enter** = Zelle ausführen

# %%
# Aufgabe 1: Dein Code hier

# %%
# Aufgabe 2: Dein Code hier

# %%
# Aufgabe 3: Dein Code hier

# %%
# Weitere Aufgaben...
